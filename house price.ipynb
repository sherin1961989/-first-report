# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("bengaluru_house_prices.csv")

df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
df[['size','price','area_type']]
# Out:
#             size   price             area_type
# 0          2 BHK   39.07  Super built-up  Area
# 1      4 Bedroom  120.00            Plot  Area
# 2          3 BHK   62.00        Built-up  Area
# 3          3 BHK   95.00  Super built-up  Area
# 4          2 BHK   51.00  Super built-up  Area
# ...          ...     ...                   ...
# 13315  5 Bedroom  231.00        Built-up  Area
# 13316      4 BHK  400.00  Super built-up  Area
# 13317      2 BHK   60.00        Built-up  Area
# 13318      4 BHK  488.00  Super built-up  Area
# 13319      1 BHK   17.00  Super built-up  Area
#
# [13320 rows x 3 columns]

# %%
df.count()
# Out:
# area_type       13320
# availability    13320
# location        13319
# size            13304
# society          7818
# total_sqft      13320
# bath            13247
# balcony         12711
# price           13320
# dtype: int64

# %%
df['price']
# Out:
# 0         39.07
# 1        120.00
# 2         62.00
# 3         95.00
# 4         51.00
#           ...
# 13315    231.00
# 13316    400.00
# 13317     60.00
# 13318    488.00
# 13319     17.00
# Name: price, Length: 13320, dtype: float64

# %%
df.sort_values(by='price') #Ascending order
# Out:
#                   area_type          availability            location  \
# 10526  Super built-up  Area         Ready To Move  Yelahanka New Town
# 11569            Plot  Area  Immediate Possession          Hosur Road
# 8594         Built-up  Area         Ready To Move          Chandapura
# 5410   Super built-up  Area         Ready To Move            Attibele
# 4113   Super built-up  Area                18-Jan          BTM Layout
# ...                     ...                   ...                 ...
# 3180   Super built-up  Area         Ready To Move     Shanthala Nagar
# 11763            Plot  Area         Ready To Move     Sadashiva Nagar
# 13200            Plot  Area         Ready To Move      Defence Colony
# 11080  Super built-up  Area                18-Jan         Ashok Nagar
# 13067            Plot  Area         Ready To Move      Defence Colony
#
#              size  society    total_sqft  bath  balcony    price
# ...

# %%
df.sort_values(by='price',ascending=False)
# Out:
#                   area_type          availability            location  \
# 13067            Plot  Area         Ready To Move      Defence Colony
# 11080  Super built-up  Area                18-Jan         Ashok Nagar
# 13200            Plot  Area         Ready To Move      Defence Colony
# 11763            Plot  Area         Ready To Move     Sadashiva Nagar
# 3180   Super built-up  Area         Ready To Move     Shanthala Nagar
# ...                     ...                   ...                 ...
# 4113   Super built-up  Area                18-Jan          BTM Layout
# 5410   Super built-up  Area         Ready To Move            Attibele
# 8594         Built-up  Area         Ready To Move          Chandapura
# 11569            Plot  Area  Immediate Possession          Hosur Road
# 10526  Super built-up  Area         Ready To Move  Yelahanka New Town
#
#              size  society    total_sqft  bath  balcony    price
# ...

# %%
df2 = df.dropna()
print(df2)
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df2.sort_values(by='price')
# Out:
#                   area_type   availability            location       size  \
# 10526  Super built-up  Area  Ready To Move  Yelahanka New Town      1 BHK
# 5410   Super built-up  Area  Ready To Move            Attibele      1 BHK
# 11945  Super built-up  Area  Ready To Move            Attibele      1 BHK
# 2437         Built-up  Area  Ready To Move            Attibele      1 BHK
# 171    Super built-up  Area  Ready To Move            Attibele      1 BHK
# ...                     ...            ...                 ...        ...
# 8682             Plot  Area  Ready To Move              Yemlur  4 Bedroom
# 9347             Plot  Area  Ready To Move    Ramagondanahalli  5 Bedroom
# 7315             Plot  Area         18-Apr              Yemlur  4 Bedroom
# 6421             Plot  Area         18-Sep        Bommenahalli  4 Bedroom
# 3180   Super built-up  Area  Ready To Move     Shanthala Nagar      5 BHK
#
#        society total_sqft  bath  balcony    price
# ...

# %%
plt.figure(figsize=(10, 6))
plt.hist(df2['price'], bins=20, edgecolor='black')
plt.xlabel('area_type')
plt.ylabel('total_sqft')
plt.title('area_type vs total_sqft')
plt.show()

# %%
df2.count()
# Out:
# area_type       7496
# availability    7496
# location        7496
# size            7496
# society         7496
# total_sqft      7496
# bath            7496
# balcony         7496
# price           7496
# dtype: int64

# %%
df2.describe()
# Out:
#               bath      balcony        price
# count  7496.000000  7496.000000  7496.000000
# mean      2.458378     1.629936    96.857122
# std       0.881128     0.780127   105.382490
# min       1.000000     0.000000     8.000000
# 25%       2.000000     1.000000    49.500000
# 50%       2.000000     2.000000    69.755000
# 75%       3.000000     2.000000   105.000000
# max       9.000000     3.000000  2700.000000

# %%
df2.sort_values(by='total_sqft')
# Out:
#                   area_type   availability                location   size  \
# 3362   Super built-up  Area  Ready To Move             Kaggalipura  2 BHK
# 4810         Built-up  Area  Ready To Move             Bommasandra  2 BHK
# 8388   Super built-up  Area  Ready To Move          Horamavu Agara  2 BHK
# 8483   Super built-up  Area  Ready To Move         Kalena Agrahara  2 BHK
# 6613   Super built-up  Area  Ready To Move          Thigalarapalya  2 BHK
# ...                     ...            ...                     ...    ...
# 864          Built-up  Area  Ready To Move       Kodichikkanahalli  2 BHK
# 10397  Super built-up  Area  Ready To Move                Attibele  2 BHK
# 11624        Built-up  Area  Ready To Move  Gollarapalya Hosahalli  2 BHK
# 8695   Super built-up  Area  Ready To Move  Gollarapalya Hosahalli  2 BHK
# 5256   Super built-up  Area         19-Jan             Mailasandra  2 BHK
#
#        society total_sqft  bath  balcony  price
# ...
